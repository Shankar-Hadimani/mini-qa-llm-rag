# %% [markdown]
# <a href="https://colab.research.google.com/github/Shankar-Hadimani/mini-qa-llm-rag/blob/master/04-monitoring/offline-rag-evaluation-assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install openai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 360.7/360.7 kB 6.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.9/318.9 kB 16.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 3.3 MB/s eta 0:00:00
# ...

# %%
import os
import openai
from getpass import getpass
from google.colab import userdata


os.environ['OPENAI_API_KEY'] = userdata.get('OPENAI_API_KEY')
openai.api_key = os.environ["OPENAI_API_KEY"]

# %%
from huggingface_hub import notebook_login
notebook_login()

# %%
github_url= "https://github.com/DataTalksClub/llm-zoomcamp/blob/main/04-monitoring/data/results-gpt4o-mini.csv"

# %%
import pandas as pd
url = f'{github_url}?raw=1'
df = pd.read_csv(url)

# %%
df = df.iloc[:300]

# %%
df.describe()
# Out:
#                                                answer_llm  \
# count                                                 300
# unique                                                300
# top     You can sign up for the course by visiting the...
# freq                                                    1
#
#                                               answer_orig  document  \
# count                                                 300       300
# unique                                                 60        60
# top     Machine Learning Zoomcamp FAQ\nThe purpose of ...  0227b872
# freq                                                    5         5
#
#                                    question                     course
# count                                   300                        300
# unique                                  300                          1
# top     Where can I sign up for the course?  machine-learning-zoomcamp
# ...

# %%
df.head()
# Out:
#                                           answer_llm  \
# 0  You can sign up for the course by visiting the...
# 1  You can sign up using the link provided in the...
# 2  Yes, there is an FAQ for the Machine Learning ...
# 3  The context does not provide any specific info...
# 4  To structure your questions and answers for th...
#
#                                          answer_orig  document  \
# 0  Machine Learning Zoomcamp FAQ\nThe purpose of ...  0227b872
# 1  Machine Learning Zoomcamp FAQ\nThe purpose of ...  0227b872
# 2  Machine Learning Zoomcamp FAQ\nThe purpose of ...  0227b872
# 3  Machine Learning Zoomcamp FAQ\nThe purpose of ...  0227b872
# 4  Machine Learning Zoomcamp FAQ\nThe purpose of ...  0227b872
#
#                                             question  \
# 0                Where can I sign up for the course?
# 1                 Can you provide a link to sign up?
# 2  Is there an FAQ for this Machine Learning course?
# ...

# %%
# Assuming df is your DataFrame
results_gpt4o_mini_dict = df.to_dict(orient='records')

# %%
results_gpt4o_mini_dict[0]
# Out:
# {'answer_llm': 'You can sign up for the course by visiting the course page at [http://mlzoomcamp.com/](http://mlzoomcamp.com/).',
#  'answer_orig': 'Machine Learning Zoomcamp FAQ\nThe purpose of this document is to capture frequently asked technical questions.\nWe did this for our data engineering course and it worked quite well. Check this document for inspiration on how to structure your questions and answers:\nData Engineering Zoomcamp FAQ\nIn the course GitHub repository there’s a link. Here it is: https://airtable.com/shryxwLd0COOEaqXo\nwork',
#  'document': '0227b872',
#  'question': 'Where can I sign up for the course?',
#  'course': 'machine-learning-zoomcamp'}

# %%
# !pip install -U transformers accelerate bitsandbytes sentencepiece
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 1.6 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...

# %%
# !pip install sentence_transformers
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.1/227.1 kB 4.0 MB/s eta 0:00:00
# ...

# %%
from sentence_transformers import SentenceTransformer

# %%
model_name = 'multi-qa-mpnet-base-dot-v1'
model = SentenceTransformer(model_name)
# Out:
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/212 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/8.71k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# ...

# %% [markdown]
# ## Q1

# %%
results_gpt4o_mini_dict[0]
# Out:
# {'answer_llm': 'You can sign up for the course by visiting the course page at [http://mlzoomcamp.com/](http://mlzoomcamp.com/).',
#  'answer_orig': 'Machine Learning Zoomcamp FAQ\nThe purpose of this document is to capture frequently asked technical questions.\nWe did this for our data engineering course and it worked quite well. Check this document for inspiration on how to structure your questions and answers:\nData Engineering Zoomcamp FAQ\nIn the course GitHub repository there’s a link. Here it is: https://airtable.com/shryxwLd0COOEaqXo\nwork',
#  'document': '0227b872',
#  'question': 'Where can I sign up for the course?',
#  'course': 'machine-learning-zoomcamp'}

# %%
answer_llm = df.iloc[0].answer_llm

# %%
answer_llm
# Out:
# 'You can sign up for the course by visiting the course page at [http://mlzoomcamp.com/](http://mlzoomcamp.com/).'

# %%
v_llm = model.encode(answer_llm)

# %%
v_llm[0]
# Out:
# -0.42244658

# %%
v_llm = model.encode(answer_llm)
v_orig = model.encode(answer_orig)

v_llm.dot(v_orig)

# %% [markdown]
# ## Q2

# %%
def compute_similarity(record):
    answer_orig = record['answer_orig']
    answer_llm = record['answer_llm']

    v_llm = model.encode(answer_llm)
    v_orig = model.encode(answer_orig)

    return v_llm.dot(v_orig)

# %%
from tqdm.auto import tqdm

# %%
similarity = []

for record in tqdm(results_gpt4o_mini_dict):
    sim = compute_similarity(record)
    similarity.append(sim)
# Out:
#   0%|          | 0/300 [00:00<?, ?it/s]

# %%
df['cosine'] = similarity
df['cosine'].describe()
# Out:
# count    300.000000
# mean      27.495996
# std        6.384742
# min        4.547925
# 25%       24.307846
# 50%       28.336873
# 75%       31.674308
# max       39.476013
# Name: cosine, dtype: float64

# %%
df
# Out:
#                                             answer_llm  \
# 0    You can sign up for the course by visiting the...
# 1    You can sign up using the link provided in the...
# 2    Yes, there is an FAQ for the Machine Learning ...
# 3    The context does not provide any specific info...
# 4    To structure your questions and answers for th...
# ..                                                 ...
# 295  An alternative way to load the data using the ...
# 296  You can directly download the dataset from Git...
# 297  You can fetch data for homework using the `req...
# 298  If the status code is 200 when downloading dat...
# 299  If the file download fails when using the requ...
#
#                                            answer_orig  document  \
# 0    Machine Learning Zoomcamp FAQ\nThe purpose of ...  0227b872
# 1    Machine Learning Zoomcamp FAQ\nThe purpose of ...  0227b872
# 2    Machine Learning Zoomcamp FAQ\nThe purpose of ...  0227b872
# ...

# %%
import numpy as np

def compute_norm_similarity(record):
    answer_orig = record['answer_orig']
    answer_llm = record['answer_llm']

    v_llm = model.encode(answer_llm)
    v_llm_norm = np.sqrt((v_llm * v_llm).sum())
    v_llm_norm_result = v_llm / v_llm_norm

    v_orig = model.encode(answer_orig)
    v_orig_norm = np.sqrt((v_orig * v_orig).sum())
    v_llm_orig_result = v_orig / v_orig_norm


    return v_llm_norm_result.dot(v_llm_orig_result)

# %%
norm_similarity = []

for record in tqdm(results_gpt4o_mini_dict):
    sim = compute_norm_similarity(record)
    norm_similarity.append(sim)
# Out:
#   0%|          | 0/300 [00:00<?, ?it/s]

# %%
df['normalized_cosine'] = norm_similarity
df['normalized_cosine'].describe()
# Out:
# count    300.000000
# mean       0.728393
# std        0.157755
# min        0.125357
# 25%        0.651273
# 50%        0.763761
# 75%        0.836235
# max        0.958796
# Name: normalized_cosine, dtype: float64

# %% [markdown]
# ## Q4. Rouge

# %%
# !pip install rouge

# %%
df.iloc[10]
# Out:
# answer_llm           Yes, all sessions are recorded, so if you miss...
# answer_orig          Everything is recorded, so you won’t miss anyt...
# document                                                      5170565b
# question                          Are sessions recorded if I miss one?
# course                                       machine-learning-zoomcamp
# cosine                                                       32.344707
# normalized_cosine                                             0.777956
# Name: 10, dtype: object

# %%
results_gpt4o_mini_dict[10]
# Out:
# {'answer_llm': "Yes, all sessions are recorded, so if you miss one, you won't miss anything. You can catch up on the content later. Additionally, you can submit your questions in advance for office hours, and those sessions are also recorded.",
#  'answer_orig': 'Everything is recorded, so you won’t miss anything. You will be able to ask your questions for office hours in advance and we will cover them during the live stream. Also, you can always ask questions in Slack.',
#  'document': '5170565b',
#  'question': 'Are sessions recorded if I miss one?',
#  'course': 'machine-learning-zoomcamp'}

# %%
from rouge import Rouge
rouge_scorer = Rouge()

scores = rouge_scorer.get_scores(results_gpt4o_mini_dict[10]['answer_llm'], results_gpt4o_mini_dict[10]['answer_orig'])[0]

# %%
scores
# Out:
# {'rouge-1': {'r': 0.45454545454545453,
#   'p': 0.45454545454545453,
#   'f': 0.45454544954545456},
#  'rouge-2': {'r': 0.21621621621621623,
#   'p': 0.21621621621621623,
#   'f': 0.21621621121621637},
#  'rouge-l': {'r': 0.3939393939393939,
#   'p': 0.3939393939393939,
#   'f': 0.393939388939394}}

# %% [markdown]
# ## Q5. Average rouge score

# %%
import pandas as pd

# Given JSON data

# Convert JSON to DataFrame
df_rouge = pd.DataFrame(scores).transpose()

# Compute the average f (F-score)
average_f = df_rouge['f'].mean()

df_rouge, average_f
# Out:
# (                r         p         f
#  rouge-1  0.454545  0.454545  0.454545
#  rouge-2  0.216216  0.216216  0.216216
#  rouge-l  0.393939  0.393939  0.393939,
#  0.35490034990035496)

# %% [markdown]
# ## Q6. Average rouge score for all the data points

# %%
from rouge import Rouge
from tqdm.auto import tqdm

def calculate_rouge_scores(results_dict):
    # Initialize the Rouge scorer
    rouge_scorer = Rouge()

    # Initialize an empty dictionary to store the scores
    rouge_scores = {}

    # Iterate over each key-value pair in the dictionary with tqdm for progress tracking
    for key, value in tqdm(results_dict.items(), total=len(results_dict), desc="Calculating ROUGE scores"):
        # Extract the LLM answer and original answer
        answer_llm = value['answer_llm']
        answer_orig = value['answer_orig']

        # Calculate the ROUGE scores
        scores = rouge_scorer.get_scores(answer_llm, answer_orig)[0]

        # Store the scores in the rouge_scores dictionary
        rouge_scores[key] = scores

    return rouge_scores

# %%
def average_rouge_2_f_score(rouge_scores):
    # Extract the ROUGE-2 F-scores
    rouge_2_f_scores = [scores['rouge-2']['f'] for scores in rouge_scores.values()]

    # Calculate the average F-score for ROUGE-2
    average_f_score = sum(rouge_2_f_scores) / len(rouge_2_f_scores)

    return average_f_score

# %%
from rouge import Rouge
from tqdm import tqdm

def calculate_rouge_scores(results_list):
    # Initialize the Rouge scorer
    rouge_scorer = Rouge()

    # Initialize an empty list to store the scores
    rouge_scores = []

    # Iterate over each record in the list with tqdm for progress tracking
    for i, value in enumerate(tqdm(results_list, total=len(results_list), desc="Calculating ROUGE scores")):
        # Extract the LLM answer and original answer
        answer_llm = value['answer_llm']
        answer_orig = value['answer_orig']

        # Calculate the ROUGE scores
        scores = rouge_scorer.get_scores(answer_llm, answer_orig)[0]

        # Append the scores to the rouge_scores list
        rouge_scores.append(scores)

    return rouge_scores

def average_rouge_2_f_score(rouge_scores):
    # Extract the ROUGE-2 F-scores
    rouge_2_f_scores = [scores['rouge-2']['f'] for scores in rouge_scores]

    # Calculate the average F-score for ROUGE-2
    average_f_score = sum(rouge_2_f_scores) / len(rouge_2_f_scores)

    return average_f_score

# %%
rouge_scores_dict = calculate_rouge_scores(results_gpt4o_mini_dict)
# Out:
# Calculating ROUGE scores: 100%|██████████| 300/300 [00:01<00:00, 187.32it/s]

# %%
average_rouge_2_f_score_results = average_rouge_2_f_score(rouge_scores_dict)

# %%
rouge_scores_dict[:3]
# Out:
# [{'rouge-1': {'r': 0.061224489795918366,
#    'p': 0.21428571428571427,
#    'f': 0.09523809178130524},
#   'rouge-2': {'r': 0.017543859649122806,
#    'p': 0.07142857142857142,
#    'f': 0.028169010918468917},
#   'rouge-l': {'r': 0.061224489795918366,
#    'p': 0.21428571428571427,
#    'f': 0.09523809178130524}},
#  {'rouge-1': {'r': 0.08163265306122448,
#    'p': 0.26666666666666666,
#    'f': 0.12499999641113292},
#   'rouge-2': {'r': 0.03508771929824561,
#    'p': 0.13333333333333333,
#    'f': 0.05555555225694465},
#   'rouge-l': {'r': 0.061224489795918366, 'p': 0.2, 'f': 0.09374999641113295}},
#  {'rouge-1': {'r': 0.32653061224489793,
#    'p': 0.5714285714285714,
#    'f': 0.41558441095631643},
#   'rouge-2': {'r': 0.14035087719298245,
#    'p': 0.24242424242424243,
#    'f': 0.17777777313333343},
#   'rouge-l': {'r': 0.30612244897959184,
#    'p': 0.5357142857142857,
#    'f': 0.3896103849822905}}]

# %%
average_rouge_2_f_score_results
# Out:
# 0.20696501983423318
